# %%
# !pip install nsepy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Introspect error on :1.97:/modules/kwalletd5: dbus.exceptions.DBusException: org.freedesktop.DBus.Error.NoReply: Message recipient disconnected from message bus without replying
# WARNING: Keyring is skipped due to an exception: Failed to open keyring: org.freedesktop.DBus.Error.ServiceUnknown: The name :1.97 was not provided by any .service files.
# ...
# Using legacy 'setup.py install' for nsepy, since package 'wheel' is not installed.
# ...
#     Running setup.py install for nsepy ... done
# ...

# %%
from nsepy import get_history

# %%
from datetime import date

# %%
data = get_history(symbol="SBIN", start=date(2018,1,1), end=date(2022,6,5))

# %%
data
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2018-01-01   SBIN     EQ      309.90  310.60  312.75  306.30  306.75  307.10
# 2018-01-02   SBIN     EQ      307.10  309.00  309.00  301.35  303.00  303.25
# 2018-01-03   SBIN     EQ      303.25  305.30  306.45  302.15  302.80  302.85
# 2018-01-04   SBIN     EQ      302.85  304.50  310.20  303.15  309.25  308.50
# 2018-01-05   SBIN     EQ      308.50  311.40  311.40  305.60  307.25  306.35
# ...           ...    ...         ...     ...     ...     ...     ...     ...
# 2022-05-30   SBIN     EQ      468.95  473.00  476.90  471.10  474.80  474.60
# 2022-05-31   SBIN     EQ      474.60  474.00  476.40  465.00  467.60  468.10
# 2022-06-01   SBIN     EQ      468.10  468.00  472.00  464.70  469.25  468.30
# 2022-06-02   SBIN     EQ      468.30  466.90  472.35  466.15  470.00  469.85
# 2022-06-03   SBIN     EQ      469.85  473.25  475.50  463.50  465.00  464.50
#
# ...

# %%
nifty_opt = get_history(symbol="NIFTY",
                        start=date(2015,1,1),
                        end=date(2015,1,10),
                        index=True,
                        option_type='CE',
                        strike_price=8200,
                        expiry_date=date(2015,1,29))

# %%
nifty_opt
# Out:
#            Symbol      Expiry Option Type  Strike Price    Open    High  \
# Date
# 2015-01-01  NIFTY  2015-01-29          CE        8200.0  170.10  223.00
# 2015-01-02  NIFTY  2015-01-29          CE        8200.0  224.25  301.50
# 2015-01-05  NIFTY  2015-01-29          CE        8200.0  285.50  313.85
# 2015-01-06  NIFTY  2015-01-29          CE        8200.0  207.05  207.05
# 2015-01-07  NIFTY  2015-01-29          CE        8200.0  115.05  125.80
# 2015-01-08  NIFTY  2015-01-29          CE        8200.0  130.00  155.80
# 2015-01-09  NIFTY  2015-01-29          CE        8200.0  170.15  185.70
#
#                Low   Close    Last  Settle Price  Number of Contracts  \
# Date
# 2015-01-01  170.10  214.85  217.50        214.85                25091
# 2015-01-02  219.55  287.20  298.00        287.20                35187
# 2015-01-05  245.20  257.85  255.50        257.85                16551
# 2015-01-06  102.80  110.00  107.90        110.00               280463
# ...

# %%
instrument_df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_29861/3037441623.py in <cell line: 1>()
# ----> 1 instrument_df = pd.DataFrame(data)
#
# NameError: name 'pd' is not defined

# %%
# !pip install jugaad-data
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Introspect error on :1.100:/modules/kwalletd5: dbus.exceptions.DBusException: org.freedesktop.DBus.Error.NoReply: Message recipient disconnected from message bus without replying
# WARNING: Keyring is skipped due to an exception: Failed to open keyring: org.freedesktop.DBus.Error.ServiceUnknown: The name :1.100 was not provided by any .service files.
# ...
#      |████████████████████████████████| 115 kB 713 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 82 kB 506 kB/s eta 0:00:01
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.1
#     Uninstalling beautifulsoup4-4.11.1:
#       Successfully uninstalled beautifulsoup4-4.11.1
# ...

# %%
from datetime import date
from jugaad_data.nse import bhavcopy_save, bhavcopy_fo_save

# Download bhavcopy
#bhavcopy_save(date(2020,1,1), "/robot/home/Documents/test")

# Download bhavcopy for futures and options
#bhavcopy_fo_save(date(2020,1,1), "/robot/home/Documents/test")

# Download stock data to pandas dataframe
from jugaad_data.nse import stock_df
df = stock_df(symbol="SBIN", from_date=date(2020,1,1),
            to_date=date(2020,1,30), series="EQ")

# %%
df
# Out:
#          DATE SERIES    OPEN    HIGH     LOW  PREV. CLOSE     LTP   CLOSE  \
# 0  2020-01-30     EQ  316.75  316.75  305.65       316.45  310.00  310.70
# 1  2020-01-29     EQ  317.85  319.70  315.55       315.10  316.95  316.45
# 2  2020-01-28     EQ  317.95  320.00  311.05       316.20  316.40  315.10
# 3  2020-01-27     EQ  320.90  322.00  315.80       324.05  316.40  316.20
# 4  2020-01-24     EQ  323.50  327.30  321.15       323.20  324.30  324.05
# 5  2020-01-23     EQ  316.00  324.80  314.15       316.15  323.15  323.20
# 6  2020-01-22     EQ  317.00  317.00  313.70       313.70  315.65  316.15
# 7  2020-01-21     EQ  313.80  316.95  312.00       314.00  313.90  313.70
# 8  2020-01-20     EQ  321.00  321.45  313.40       318.00  314.00  314.00
# 9  2020-01-17     EQ  313.00  323.50  310.10       323.30  318.00  318.00
# 10 2020-01-16     EQ  324.00  326.90  322.35       324.25  323.10  323.30
# 11 2020-01-15     EQ  329.00  329.20  322.35       328.00  324.00  324.25
# ...

# %%
import pandas as pd

# %%
import jugaad_data.nse as ns

# %%
ns
# Out:
# <module 'jugaad_data.nse' from '/home/robot/.local/lib/python3.9/site-packages/jugaad_data/nse/__init__.py'>

# %%
print(ns)
# Out:
# <module 'jugaad_data.nse' from '/home/robot/.local/lib/python3.9/site-packages/jugaad_data/nse/__init__.py'>

# %%
dir(ns)
# Out:
# ['APP_NAME',
#  'NSEArchives',
#  'NSEHistory',
#  'NSEIndexHistory',
#  'NSEIndicesArchives',
#  'NSELive',
#  'Session',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'a',
#  'archives',
#  'bhavcopy_fo_raw',
#  'bhavcopy_fo_save',
#  'bhavcopy_index_raw',
#  'bhavcopy_index_save',
#  'bhavcopy_raw',
#  'bhavcopy_save',
#  'click',
#  'csv',
#  'date',
#  'datetime',
#  'derivatives_csv',
#  'derivatives_df',
#  'derivatives_raw',
#  'expiry_dates',
#  'full_bhavcopy_raw',
#  'full_bhavcopy_save',
#  'futures_final_headers',
#  'futures_select_headers',
#  'h',
#  'history',
#  'ia',
#  'ih',
#  'index_csv',
#  'index_df',
#  'index_dtypes',
#  'index_raw',
#  'io',
#  'itertools',
#  'json',
#  'live',
#  'live_cache',
#  'np',
#  'options_final_headers',
#  'options_select_headers',
#  'os',
#  'pd',
#  'pprint',
#  'requests',
#  'stock_csv',
#  'stock_df',
#  'stock_dtypes',
# ...

# %%
print(ns.stock_csv(symbol="WIPRO",from_date="2020,1,1",to_date="2020,1,30",output="new.csv", show_progress=False))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_29861/1399790130.py in <cell line: 1>()
# ----> 1 print(ns.stock_csv(symbol="WIPRO",from_date="2020,1,1",to_date="2020,1,30",output="new.csv", show_progress=False))
#
# ~/.local/lib/python3.9/site-packages/jugaad_data/nse/history.py in stock_csv(symbol, from_date, to_date, series, output, show_progress)
#     157             raw = list(itertools.chain.from_iterable(chunks))
#     158     else:
# --> 159         raw = stock_raw(symbol, from_date, to_date, series)
#     160
#     161     if not output:
#
# ~/.local/lib/python3.9/site-packages/jugaad_data/nse/history.py in stock_raw(self, symbol, from_date, to_date, series)
#     107
#     108     def stock_raw(self, symbol, from_date, to_date, series="EQ"):
# --> 109         date_ranges = ut.break_dates(from_date, to_date)
# ...

# %%
#instrument_dump = kite.instruments("NSE")

# %%
from nsetools import Nse
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_29861/2973202827.py in <cell line: 1>()
# ----> 1 from nsetools import Nse
#
# ModuleNotFoundError: No module named 'nsetools'

# %%
# !pip install nsetools
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Introspect error on :1.110:/modules/kwalletd5: dbus.exceptions.DBusException: org.freedesktop.DBus.Error.NoReply: Message recipient disconnected from message bus without replying
# WARNING: Keyring is skipped due to an exception: Failed to open keyring: org.freedesktop.DBus.Error.ServiceUnknown: The name :1.110 was not provided by any .service files.
# ...

# %%
from nsetools import Nse

# %%
nsa = Nse()

# %%
print(nsa)
# Out:
# Driver Class for National Stock Exchange (NSE)

# %%
dir(nsa.top_gainer_url.index("NSE"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_29861/852921519.py in <cell line: 1>()
# ----> 1 dir(nsa.top_gainer_url.index("NSE"))
#
# ValueError: substring not found
