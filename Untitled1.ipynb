# %%
# !pip install alice_blue
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import logging
logging.basicConfig(level=logging.DEBUG)

# %%
from alice_blue import *

# %%
access_token = AliceBlue.login_and_get_access_token(username='600571', password='idgeR09', twoFA='1990', api_secret='r2991mseeTb2jHusZbwFpa2EWWMhZhRQxUSskqfoKnFHDPtIrPrwtMu4z2cEebqV', app_id='GcSTTQGRU0')
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): ant.aliceblueonline.com:443
# DEBUG:urllib3.connectionpool:https://ant.aliceblueonline.com:443 "GET /oauth2/auth?response_type=code&state=test_state&client_id=GcSTTQGRU0&redirect_uri=https://ant.aliceblueonline.com/plugin/callback HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:https://ant.aliceblueonline.com:443 "GET /oauth/login?login_challenge=66443a6bd248425391248e76cfc2003f HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://ant.aliceblueonline.com:443 "POST /oauth/login?login_challenge=66443a6bd248425391248e76cfc2003f HTTP/1.1" 302 None
# DEBUG:urllib3.connectionpool:https://ant.aliceblueonline.com:443 "GET /oauth/twofa?login_challenge=66443a6bd248425391248e76cfc2003f&login_id=600571&question_ids=1&questions=Year+Of+Birth HTTP/1.1" 200 None
# ...

# %%
alice = AliceBlue(username='600571', password='idgeR09', access_token=access_token)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): ant.aliceblueonline.com:443
# DEBUG:urllib3.connectionpool:https://ant.aliceblueonline.com:443 "GET /api/v2/profile HTTP/1.1" 200 None
# INFO:alice_blue.alice_blue:Downloading master contracts for exchange: BSE
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): ant.aliceblueonline.com:443
# DEBUG:urllib3.connectionpool:https://ant.aliceblueonline.com:443 "GET /api/v2/contracts.json?exchanges=BSE HTTP/1.1" 200 None
# INFO:alice_blue.alice_blue:Downloading master contracts for exchange: NSE
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): ant.aliceblueonline.com:443
# DEBUG:urllib3.connectionpool:https://ant.aliceblueonline.com:443 "GET /api/v2/contracts.json?exchanges=NSE HTTP/1.1" 200 None
# INFO:alice_blue.alice_blue:Downloading master contracts for exchange: BFO
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): ant.aliceblueonline.com:443
# ...

# %%
print(alice.get_balance())
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): ant.aliceblueonline.com:443
# DEBUG:urllib3.connectionpool:https://ant.aliceblueonline.com:443 "GET /api/v2/cashposition HTTP/1.1" 200 None
# ...

# %%
print(alice.get_profile())
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): ant.aliceblueonline.com:443
# DEBUG:urllib3.connectionpool:https://ant.aliceblueonline.com:443 "GET /api/v2/profile HTTP/1.1" 200 None
# {'status': 'success', 'message': '', 'data': {'phone': '8660752245', 'pan_number': 'CDTPB9112N', 'name': 'BOYA VENKATA TEJASWI', 'login_id': '600571', 'exchanges': ['BSE', 'NSE', 'BFO', 'MCX', 'CDS', 'MCX', 'CDS', 'MCX', 'NFO', 'CDS', 'MCX', 'NFO'], 'email_address': 'YOUCANTEJA@GMAIL.COM', 'dp_ids': [], 'broker_name': 'ALICEBLUE', 'banks': [{'branch_name': '', 'bank_name': 'ANDHRA PRAGATHI GRAMEENA BANK', 'account_id': '600571'}, {'branch_name': '', 'bank_name': '', 'account_id': '600571'}, {'branch_name': '', 'bank_name': '', 'account_id': '600571'}, {'branch_name': '', 'bank_name': '', 'account_id': '600571'}, {'branch_name': '', 'bank_name': '', 'account_id': '600571'}, {'branch_name': '', 'bank_name': '', 'account_id': '600571'}], 'backoffice_enabled': True}}

# %%
tatasteel_nse_eq = alice.get_instrument_by_symbol('NSE', 'TATASTEEL')

# %%
tatasteel_nse_eq
# Out:
# Instrument(exchange='NSE', token=3499, symbol='TATASTEEL', name='TATA STEEL LIMITED', expiry=None, lot_size=None)

# %%
bn_fut = alice.get_instrument_for_fno(symbol = 'BANKNIFTY', expiry_date=datetime.date(2019, 6, 27), is_fut=True, strike=None, is_CE = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_75270/2353673037.py in <cell line: 1>()
# ----> 1 bn_fut = alice.get_instrument_for_fno(symbol = 'BANKNIFTY', expiry_date=datetime.date(2019, 6, 27), is_fut=True, strike=None, is_CE = False)
#
# NameError: name 'datetime' is not defined

# %%
import datetime

# %%
bn_fut = alice.get_instrument_for_fno(symbol = 'BANKNIFTY', expiry_date=datetime.date(2022, 7, 7), is_fut=True, strike=None, is_CE = False)

# %%
bn_fut

# %%
all_sensex_scrips = alice.search_instruments('BSE', 'sEnSeX')

# %%
print(all_sensex_scrips)
# Out:
# [Instrument(exchange='BSE', token=1, symbol='SENSEX', name='SENSEX', expiry=None, lot_size=None), Instrument(exchange='BSE', token=540154, symbol='IDFSENSEXE A', name='IDFC Mutual Fund', expiry=None, lot_size='1'), Instrument(exchange='BSE', token=532985, symbol='KTKSENSEX B', name='KOTAK MAHINDRA MUTUAL FUND', expiry=None, lot_size='1'), Instrument(exchange='BSE', token=535276, symbol='SBISENSEX A', name='SBI MUTUAL FUND - SBI ETF SENS', expiry=None, lot_size='1'), Instrument(exchange='BSE', token=538683, symbol='SENSEXBEES A', name='NIPPON INDIA ETF SENSEX', expiry=None, lot_size='1')]

# %%
tatasteel_nse_ = alice.get_instrument_by_symbol('NSE')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_75270/3796576062.py in <cell line: 1>()
# ----> 1 tatasteel_nse_ = alice.get_instrument_by_symbol('NSE')
#
# TypeError: get_instrument_by_symbol() missing 1 required positional argument: 'symbol'

# %%
multiple_underlying = ['BANKNIFTY','NIFTY','INFY','BHEL']

# %%
all_scripts = alice.search_instruments('NFO', multiple_underlying)

# %%
all_scripts
# Out:
# [Instrument(exchange='NFO', token=40550, symbol='BANKNIFTY 07 JUL22 31600.0 CE', name='', expiry=datetime.date(2022, 7, 7), lot_size='25'),
#  Instrument(exchange='NFO', token=40550, symbol='BANKNIFTY 07 JUL22 31600.0 CE', name='', expiry=datetime.date(2022, 7, 7), lot_size='25'),
#  Instrument(exchange='NFO', token=40571, symbol='BANKNIFTY 07 JUL22 31600.0 PE', name='', expiry=datetime.date(2022, 7, 7), lot_size='25'),
#  Instrument(exchange='NFO', token=40571, symbol='BANKNIFTY 07 JUL22 31600.0 PE', name='', expiry=datetime.date(2022, 7, 7), lot_size='25'),
#  Instrument(exchange='NFO', token=40572, symbol='BANKNIFTY 07 JUL22 31700.0 CE', name='', expiry=datetime.date(2022, 7, 7), lot_size='25'),
#  Instrument(exchange='NFO', token=40572, symbol='BANKNIFTY 07 JUL22 31700.0 CE', name='', expiry=datetime.date(2022, 7, 7), lot_size='25'),
#  Instrument(exchange='NFO', token=40573, symbol='BANKNIFTY 07 JUL22 31700.0 PE', name='', expiry=datetime.date(2022, 7, 7), lot_size='25'),
# ...

# %%
instrument_df = pd.DataFrame(all_scripts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_75270/1728292156.py in <cell line: 1>()
# ----> 1 instrument_df = pd.DataFrame(all_scripts)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
instrument_df = pd.DataFrame(all_scripts)

# %%
instrument_df
# Out:
#      exchange  token                         symbol name      expiry lot_size
# 0         NFO  40550  BANKNIFTY 07 JUL22 31600.0 CE       2022-07-07       25
# 1         NFO  40550  BANKNIFTY 07 JUL22 31600.0 CE       2022-07-07       25
# 2         NFO  40571  BANKNIFTY 07 JUL22 31600.0 PE       2022-07-07       25
# 3         NFO  40571  BANKNIFTY 07 JUL22 31600.0 PE       2022-07-07       25
# 4         NFO  40572  BANKNIFTY 07 JUL22 31700.0 CE       2022-07-07       25
# ...       ...    ...                            ...  ...         ...      ...
# 9190      NFO  51742             MIDCPNIFTY JUL FUT       2022-07-26       75
# 9191      NFO  53993             MIDCPNIFTY JUN FUT       2022-06-28       75
# 9192      NFO  82222                  NIFTY AUG FUT       2022-08-25       50
# 9193      NFO  53735                  NIFTY JUL FUT       2022-07-28       50
# 9194      NFO  56734                  NIFTY JUN FUT       2022-06-30       50
#
# [9195 rows x 6 columns]

# %%
multiple_underlying = ['BANKNIFTY']

# %%
instrument_df = pd.DataFrame(all_scripts)

# %%
multiple_underlying
# Out:
# ['BANKNIFTY']

# %%
instrument_df
# Out:
#      exchange  token                         symbol name      expiry lot_size
# 0         NFO  40550  BANKNIFTY 07 JUL22 31600.0 CE       2022-07-07       25
# 1         NFO  40550  BANKNIFTY 07 JUL22 31600.0 CE       2022-07-07       25
# 2         NFO  40571  BANKNIFTY 07 JUL22 31600.0 PE       2022-07-07       25
# 3         NFO  40571  BANKNIFTY 07 JUL22 31600.0 PE       2022-07-07       25
# 4         NFO  40572  BANKNIFTY 07 JUL22 31700.0 CE       2022-07-07       25
# ...       ...    ...                            ...  ...         ...      ...
# 9190      NFO  51742             MIDCPNIFTY JUL FUT       2022-07-26       75
# 9191      NFO  53993             MIDCPNIFTY JUN FUT       2022-06-28       75
# 9192      NFO  82222                  NIFTY AUG FUT       2022-08-25       50
# 9193      NFO  53735                  NIFTY JUL FUT       2022-07-28       50
# 9194      NFO  56734                  NIFTY JUN FUT       2022-06-30       50
#
# [9195 rows x 6 columns]

# %%
all_scripts = alice.search_instruments('NSE', multiple_underlying)

# %%
all_scripts
# Out:
# []
